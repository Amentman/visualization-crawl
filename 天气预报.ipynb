# %%
# 导入request_html中的 和city 包
from requests_html import HTMLSession
from city import city
session = HTMLSession()

# 定义一个天气函数
def weather(cs):
    
    dm = city(cs) # 调用 city 函数
    
    # 得到登录的请求头信息,
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}
    
    # 登录要请求的地址，
    url = 'http://t.weather.sojson.com/api/weather/city/%s' % dm
    
    # 开始登录
    r = session.get(url, headers=headers)
    
    # 打印出响应的内容
    r = r.json()
    
    # 尝试读取数据
    try:
        print(r['time'] + r['cityInfo']['city'])
        for i in r['data']['forecast'][0]:
            print(r['data']['forecast'][0][i])
    except:
    	print('查询失败!请确认城市名称是否正确!')

# 查询语句
if __name__ == '__main__':
    while True:
        
        print('*' * 7 + '小七天气预报查询!(输入0退出!)' + '*' * 7)
        
        # 让用户输入城市名称
        cs = input('请输入城市名称: ')
        
        if cs != '0':
            # 如果输入不为0，调用 weather 函数输出结果
            weather(cs)
        else:
            # 如果输入为0，退出程序
            print('欢迎再次使用!\n已经退出天气查询!')
            break
# Out:
# *******小七天气预报查询!(输入0退出!)*******
# 请输入城市名称: 上海
# 2019-05-06 13:11:17上海市
# 06
# 05:07
# 高温 20.0℃
# 低温 12.0℃
# 18:36
# 63.0
# 2019-05-06
# 星期一
# 东北风
# 4-5级
# 多云
# 阴晴之间，谨防紫外线侵扰
# *******小七天气预报查询!(输入0退出!)*******
# 请输入城市名称: 北京
# 2019-05-06 13:50:55北京市
# 06
# 05:11
# 高温 25.0℃
# 低温 10.0℃
# 19:12
# 26.0
# 2019-05-06
# 星期一
# 西南风
# 3-4级
# 晴
# 愿你拥有比阳光明媚的心情
# *******小七天气预报查询!(输入0退出!)*******
# 请输入城市名称: 天津
# 2019-05-06 14:10:29天津市
# 06
# 05:09
# 高温 25.0℃
# 低温 16.0℃
# 19:08
# 49.0
# 2019-05-06
# 星期一
# 西北风
# 3-4级
# 晴
# 愿你拥有比阳光明媚的心情
# *******小七天气预报查询!(输入0退出!)*******
# 请输入城市名称: 大连
# 2019-05-06 13:00:24大连市
# 06
# 04:52
# 高温 19.0℃
# 低温 13.0℃
# 18:50
# 78.0
# 2019-05-06
# 星期一
# 西南风
# 5-6级
# 晴
# 愿你拥有比阳光明媚的心情
# *******小七天气预报查询!(输入0退出!)*******
